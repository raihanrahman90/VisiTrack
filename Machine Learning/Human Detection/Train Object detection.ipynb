# %% [markdown]
# # Training an Object Detection Model with Your Own Data

# %% [markdown]
# # Install Libraries

# %%
# %%capture
#After this cell executes runtime will restart to finish the install, ignore and close the crash message, continue running cells starting with the one below
# !pip install numpy==1.17.5;
# !pip install tensorflow-gpu==1.15.0;
import os
os.kill(os.getpid(), 9)
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (1.19.5)

# %% [markdown]
# # UseTensorflow 1.X and install tf_slim

# %%
# %tensorflow_version 1.x
# !pip install tf_slim
# Out:
# Collecting tf_slim
#   Downloading https://files.pythonhosted.org/packages/02/97/b0f4a64df018ca018cc035d44f2ef08f91e2e8aa67271f6f19633a015ff7/tf_slim-1.1.0-py2.py3-none-any.whl (352kB)
#      |████████████████████████████████| 358kB 6.3MB/s
# Requirement already satisfied: absl-py>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from tf_slim) (0.12.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from absl-py>=0.2.2->tf_slim) (1.15.0)
# Installing collected packages: tf-slim
# Successfully installed tf-slim-1.1.0

# %% [markdown]
# Setting models, Use ssd_mobilenet_v2 or you can select it from object detection library
# https://github.com/tensorflow/models/tree/master/research/object_detection

# %%
num_steps = 5000  # A step means using a single batch of data. larger batch, less steps required
num_eval_steps = 50
MODELS_CONFIG = {
        'ssd_mobilenet_v2': {
        'model_name': 'ssd_mobilenet_v2_coco_2018_03_29',
        'pipeline_file': 'ssd_mobilenet_v2_coco.config',
        'batch_size': 24
    }
}
selected_model = 'ssd_mobilenet_v2'
MODEL = MODELS_CONFIG[selected_model]['model_name']
pipeline_file = MODELS_CONFIG[selected_model]['pipeline_file']
batch_size = MODELS_CONFIG[selected_model]['batch_size']

# %% [markdown]
# ## Clone the `object_detection_demo_flow` repository

# %%
repo_url = 'https://github.com/GotG/object_detection_demo_flow'
import os
# %cd /content
# Out:
# /content

# %%
repo_dir_path = os.path.abspath(os.path.join('.', os.path.basename(repo_url)))
# !git clone {repo_url}
# %cd {repo_dir_path}
# !git pull
# Out:
# Cloning into 'object_detection_demo_flow'...
# remote: Enumerating objects: 3035, done.
# remote: Total 3035 (delta 0), reused 0 (delta 0), pack-reused 3035
# Receiving objects: 100% (3035/3035), 229.08 MiB | 41.47 MiB/s, done.
# Resolving deltas: 100% (1375/1375), done.
# Checking out files: 100% (2796/2796), done.
# /content/object_detection_demo_flow
# Already up to date.

# %% [markdown]
# #[Optional] If you wish to use your own data, run the cells below.
# (Otherwise the model can train with the data already present in the cloned repo)

# %% [markdown]
# ## Mount your google drive

# %%
#mount your google drive.
#it will be visible in the file navigator on the left of this notebook
#there should be a folder in your drive with your data
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# Own data should be split into 80% training (train folder), 20% for validation (test folder). The train and test folder should contain images and associated .xml annotations.
#
# Have extra images for final model testing (final_test folder). These need not be annotated.

# %%
#To train on your own data:
#Remove repo data (images) for training/testing/final testing
# !rm -r /content/object_detection_demo_flow/data/images/train/
# !rm -r /content/object_detection_demo_flow/data/images/test/

# %%
#copy files from gdrive to colab drive. this takes a few minutes, depending on the number of files.
#Go on the file explorer on the left of this notebook and access your gdrive. find the folders
#with your train, test and final_test images.
#Right click on each and copy the path. paste it btw the first " " in the corresponding lines  

#training folder
# !cp -r "/content/gdrive/MyDrive/TFJS/gambar_train/" "/content/object_detection_demo_flow/data/images/train"
# !cp -r "/content/gdrive/MyDrive/TFJS/gambar_test/" "/content/object_detection_demo_flow/data/images/test"
#testing folder

# %%
# quick check for training data files. you can also browse to the object_detection_demo_flows
# on the left and see if they were copied
# !ls /content/object_detection_demo_flow/data/images/train
# Out:
#  1182657.jpg
#  1182657.xml
# '(26) Hermosa Beach Good Stuff Strand Cam. Live Camera Stream from Southern California - YouTube - Google Chrome 5_30_2021 2_01_16 AM (1).png'
# '(26) Hermosa Beach Good Stuff Strand Cam. Live Camera Stream from Southern California - YouTube - Google Chrome 5_30_2021 2_01_16 AM (1).xml'
# '(26) Hermosa Beach Good Stuff Strand Cam. Live Camera Stream from Southern California - YouTube - Google Chrome 5_30_2021 2_01_16 AM.png'
# '(26) Hermosa Beach Good Stuff Strand Cam. Live Camera Stream from Southern California - YouTube - Google Chrome 5_30_2021 2_01_16 AM.xml'
# '(26) Live Beach Cam Hollywood Beach Broadwalk, Florida - YouTube - Google Chrome 5_30_2021 1_55_55 AM.png'
# '(26) Live Beach Cam Hollywood Beach Broadwalk, Florida - YouTube - Google Chrome 5_30_2021 1_55_55 AM.xml'
# '(26) Live Beach Cam Hollywood Beach Broadwalk, Florida - YouTube - Google Chrome 5_30_2021 1_55_57 AM.png'
# '(26) Live Beach Cam Hollywood Beach Broadwalk, Florida - YouTube - Google Chrome 5_30_2021 1_55_57 AM.xml'
# '(26) Live Beach Cam Hollywood Beach Broadwalk, Florida - YouTube - Google Chrome 5_30_2021 1_58_40 AM.png'
# '(26) Live Beach Cam Hollywood Beach Broadwalk, Florida - YouTube - Google Chrome 5_30_2021 1_58_40 AM.xml'
#  4SHUTDKWUJBQXALP7LBBUUGSXM.jpg
#  4SHUTDKWUJBQXALP7LBBUUGSXM.xml
#  5f600fcd4dda0.jpg
#  5f600fcd4dda0.xml
# '707b8030-6b2f-400d-a03c-9a114a81ace9 (1).jpeg'
# '707b8030-6b2f-400d-a03c-9a114a81ace9 (1).xml'
#  7-pedestrian-terkeren-di-dunia-6.jpeg
#  7-pedestrian-terkeren-di-dunia-6.xml
# 'download (10).jpg'
# 'download (10).xml'
# 'download (11).jpg'
# 'download (11).xml'
# 'download (12).jpg'
# 'download (12).xml'
# 'download (13).jpg'
# 'download (13).xml'
# 'download (14).jpg'
# 'download (14).xml'
# 'download (17).jpg'
# 'download (17).xml'
# 'download (18).jpg'
# 'download (18).xml'
# 'download (1).jpg'
# 'download (1).xml'
# 'download (20).jpg'
# 'download (20).xml'
# 'download (21).jpg'
# 'download (21).xml'
# 'download (22).jpg'
# 'download (22).xml'
# 'download (23).jpg'
# 'download (23).xml'
# 'download (24).jpg'
# 'download (24).xml'
# 'download (25).jpg'
# 'download (25).xml'
# 'download (2).jpg'
# 'download (2).xml'
# 'download (3).jpg'
# 'download (3).xml'
# 'download (4).jpg'
# 'download (4).xml'
# 'download (5).jpg'
# 'download (5).xml'
# 'download (7).jpg'
# 'download (7).xml'
#  download.jpg
# 'downloads (10).jpg'
# 'downloads (10).xml'
# 'downloads (11).jpg'
# 'downloads (11).xml'
# 'downloads (13).jpg'
# 'downloads (13).xml'
# 'downloads (14).jpg'
# 'downloads (14).xml'
# 'downloads (15).jpg'
# 'downloads (15).xml'
# 'downloads (17).jpg'
# 'downloads (17).xml'
# 'downloads (18).jpg'
# 'downloads (18).xml'
# 'downloads (19).jpg'
# 'downloads (19).xml'
# 'downloads (1).jpg'
# 'downloads (1).xml'
# 'downloads (20).jpg'
# 'downloads (20).xml'
# 'downloads (21).jpg'
# 'downloads (21).xml'
# 'downloads (22).jpg'
# 'downloads (22).xml'
# 'downloads (23).jpg'
# 'downloads (23).xml'
# 'downloads (24).jpg'
# 'downloads (24).xml'
# 'downloads (26).jpg'
# 'downloads (26).xml'
# 'downloads (27).jpg'
# 'downloads (27).xml'
# 'downloads (28).jpg'
# 'downloads (28).xml'
# 'downloads (29).jpg'
# 'downloads (29).xml'
# 'downloads (2).jpg'
# 'downloads (2).xml'
# 'downloads (3).jpg'
# 'downloads (3).xml'
# 'downloads (4).jpg'
# 'downloads (4).xml'
# 'downloads (7).jpg'
# 'downloads (7).xml'
# 'downloads (8).jpg'
# 'downloads (8).xml'
# 'downloads (9).jpg'
# 'downloads (9).xml'
#  download.xml
#  f5xcusxaftbgggv4yiql.jpg
#  f5xcusxaftbgggv4yiql.xml
#  headline-tes-kepribadian-sederhana-kamu-orang-yang-seperti-apa-sih.jpg
#  headline-tes-kepribadian-sederhana-kamu-orang-yang-seperti-apa-sih.xml
# 'image (100).jpg'
# 'image (100).xml'
# 'image (101).jpg'
# 'image (101).xml'
# 'image (102).jpg'
# 'image (102).xml'
# 'image (103).jpg'
# 'image (103).xml'
# 'image (104).jpg'
# 'image (104).xml'
# 'image (105).jpg'
# 'image (105).xml'
# 'image (106).jpg'
# 'image (106).xml'
# 'image (107).jpg'
# 'image (107).xml'
# 'image (108).jpg'
# 'image (108).xml'
# 'image (109).jpg'
# 'image (109).xml'
# 'image (10).jpg'
# 'image (10).xml'
# 'image (110).jpg'
# 'image (110).xml'
# 'image (111).jpg'
# 'image (111).xml'
# 'image (112).jpg'
# 'image (112).xml'
# 'image (113).jpg'
# 'image (113).xml'
# 'image (114).jpg'
# 'image (114).xml'
# 'image (115).jpg'
# 'image (115).xml'
# 'image (116).jpg'
# 'image (116).xml'
# 'image (117).jpg'
# 'image (117).xml'
# 'image (118).jpg'
# 'image (118).xml'
# 'image (119).jpg'
# 'image (119).xml'
# 'image (11).jpg'
# 'image (11).xml'
# 'image (120).jpg'
# 'image (120).xml'
# 'image (121).jpg'
# 'image (121).xml'
# 'image (122).jpg'
# 'image (122).xml'
# 'image (123).jpg'
# 'image (123).xml'
# 'image (124).jpg'
# 'image (124).xml'
# 'image (125).jpg'
# 'image (125).xml'
# 'image (126).jpg'
# 'image (126).xml'
# 'image (127).jpg'
# 'image (127).xml'
# 'image (128).jpg'
# 'image (128).xml'
# 'image (129).jpg'
# 'image (129).xml'
# 'image (12).jpg'
# 'image (12).xml'
# 'image (130).jpg'
# 'image (130).xml'
# 'image (131).jpg'
# 'image (131).xml'
# 'image (132).jpg'
# 'image (132).xml'
# 'image (133).jpg'
# 'image (133).xml'
# 'image (134).jpg'
# 'image (134).xml'
# 'image (135).jpg'
# 'image (135).xml'
# 'image (136).jpg'
# 'image (136).xml'
# 'image (137).jpg'
# 'image (137).xml'
# 'image (138).jpg'
# 'image (138).xml'
# 'image (139).jpg'
# 'image (139).xml'
# 'image (13).jpg'
# 'image (13).xml'
# 'image (140).jpg'
# 'image (140).xml'
# 'image (141).jpg'
# 'image (141).xml'
# 'image (142).jpg'
# 'image (142).xml'
# 'image (143).jpg'
# 'image (143).xml'
# 'image (144).jpg'
# 'image (144).xml'
# 'image (145).jpg'
# 'image (145).xml'
# 'image (146).jpg'
# 'image (146).xml'
# 'image (147).jpg'
# 'image (147).xml'
# 'image (148).jpg'
# 'image (148).xml'
# 'image (149).jpg'
# 'image (149).xml'
# 'image (14).jpg'
# 'image (14).xml'
# 'image (150).jpg'
# 'image (150).xml'
# 'image (151).jpg'
# 'image (151).xml'
# 'image (152).jpg'
# 'image (152).xml'
# 'image (153).jpg'
# 'image (153).xml'
# 'image (154).jpg'
# 'image (154).xml'
# 'image (155).jpg'
# 'image (155).xml'
# 'image (156).jpg'
# 'image (156).xml'
# 'image (157).jpg'
# 'image (157).xml'
# 'image (158).jpg'
# 'image (158).xml'
# 'image (159).jpg'
# 'image (159).xml'
# 'image (15).jpg'
# 'image (15).xml'
# 'image (160).jpg'
# 'image (160).xml'
# 'image (161).jpg'
# 'image (161).xml'
# 'image (162).jpg'
# 'image (162).xml'
# 'image (163).jpg'
# 'image (163).xml'
# 'image (164).jpg'
# 'image (164).xml'
# 'image (165).jpg'
# 'image (165).xml'
# 'image (166).jpg'
# 'image (166).xml'
# 'image (167).jpg'
# 'image (167).xml'
# 'image (168).jpg'
# 'image (168).xml'
# 'image (169).jpg'
# 'image (169).xml'
# 'image (16).jpg'
# 'image (16).xml'
# 'image (170).jpg'
# 'image (170).xml'
# 'image (171).jpg'
# 'image (171).xml'
# 'image (172).jpg'
# 'image (172).xml'
# 'image (173).jpg'
# 'image (173).xml'
# 'image (174).jpg'
# 'image (174).xml'
# 'image (175).jpg'
# 'image (175).xml'
# 'image (176).jpg'
# 'image (176).xml'
# 'image (177).jpg'
# 'image (177).xml'
# 'image (178).jpg'
# 'image (178).xml'
# 'image (179).jpg'
# 'image (179).xml'
# 'image (17).jpg'
# 'image (17).xml'
# 'image (180).jpg'
# 'image (180).xml'
# 'image (181).jpg'
# 'image (181).xml'
# 'image (182).jpg'
# 'image (182).xml'
# 'image (183).jpg'
# 'image (183).xml'
# 'image (184).jpg'
# 'image (184).xml'
# 'image (185).jpg'
# 'image (185).xml'
# 'image (186).jpg'
# 'image (186).xml'
# 'image (187).jpg'
# 'image (187).xml'
# 'image (188).jpg'
# 'image (188).xml'
# 'image (189).jpg'
# 'image (189).xml'
# 'image (18).jpg'
# 'image (18).xml'
# 'image (190).jpg'
# 'image (190).xml'
# 'image (191).jpg'
# 'image (191).xml'
# 'image (192).jpg'
# 'image (192).xml'
# 'image (193).jpg'
# 'image (193).xml'
# 'image (194).jpg'
# 'image (194).xml'
# 'image (195).jpg'
# 'image (195).xml'
# 'image (196).jpg'
# 'image (196).xml'
# 'image (197).jpg'
# 'image (197).xml'
# 'image (198).jpg'
# 'image (198).xml'
# 'image (199).jpg'
# 'image (199).xml'
# 'image (19).jpg'
# 'image (19).xml'
# 'image (1).jpg'
# 'image (1).xml'
# 'image (200).jpg'
# 'image (200).xml'
# 'image (201).jpg'
# 'image (201).xml'
# 'image (202).jpg'
# 'image (202).xml'
# 'image (203).jpg'
# 'image (203).xml'
# 'image (204).jpg'
# 'image (204).xml'
# 'image (205).jpg'
# 'image (205).xml'
# 'image (206).jpg'
# 'image (206).xml'
# 'image (207).jpg'
# 'image (207).xml'
# 'image (208).jpg'
# 'image (208).xml'
# 'image (209).jpg'
# 'image (209).xml'
# 'image (20).jpg'
# 'image (20).xml'
# 'image (210).jpg'
# 'image (210).xml'
# 'image (211).jpg'
# 'image (211).xml'
# 'image (212).jpg'
# 'image (212).xml'
# 'image (213).jpg'
# 'image (213).xml'
# 'image (214).jpg'
# 'image (214).xml'
# 'image (215).jpg'
# 'image (215).xml'
# 'image (216).jpg'
# 'image (216).xml'
# 'image (217).jpg'
# 'image (217).xml'
# 'image (218).jpg'
# 'image (218).xml'
# 'image (219).jpg'
# 'image (219).xml'
# 'image (21).jpg'
# 'image (21).xml'
# 'image (220).jpg'
# 'image (220).xml'
# 'image (221).jpg'
# 'image (221).xml'
# 'image (222).jpg'
# 'image (222).xml'
# 'image (223).jpg'
# 'image (223).xml'
# 'image (224).jpg'
# 'image (224).xml'
# 'image (225).jpg'
# 'image (225).xml'
# 'image (226).jpg'
# 'image (226).xml'
# 'image (227).jpg'
# 'image (227).xml'
# 'image (228).jpg'
# 'image (228).xml'
# 'image (229).jpg'
# 'image (229).xml'
# 'image (22).jpg'
# 'image (22).xml'
# 'image (230).jpg'
# 'image (230).xml'
# 'image (231).jpg'
# 'image (231).xml'
# 'image (232).jpg'
# 'image (232).xml'
# 'image (233).jpg'
# 'image (233).xml'
# 'image (234).jpg'
# 'image (234).xml'
# 'image (235).jpg'
# 'image (235).xml'
# 'image (236).jpg'
# 'image (236).xml'
# 'image (237).jpg'
# 'image (237).xml'
# 'image (238).jpg'
# 'image (238).xml'
# 'image (239).jpg'
# 'image (239).xml'
# 'image (23).jpg'
# 'image (23).xml'
# 'image (240).jpg'
# 'image (240).xml'
# 'image (241).jpg'
# 'image (241).xml'
# 'image (242).jpg'
# 'image (242).xml'
# 'image (243).jpg'
# 'image (243).xml'
# 'image (244).jpg'
# 'image (244).xml'
# 'image (245).jpg'
# 'image (245).xml'
# 'image (246).jpg'
# 'image (246).xml'
# 'image (247).jpg'
# 'image (247).xml'
# 'image (248).jpg'
# 'image (248).xml'
# 'image (249).jpg'
# 'image (249).xml'
# 'image (24).jpg'
# 'image (24).xml'
# 'image (250).jpg'
# 'image (250).xml'
# 'image (251).jpg'
# 'image (251).xml'
# 'image (252).jpg'
# 'image (252).xml'
# 'image (253).jpg'
# 'image (253).xml'
# 'image (254).jpg'
# 'image (254).xml'
# 'image (255).jpg'
# 'image (255).xml'
# 'image (256).jpg'
# 'image (256).xml'
# 'image (257).jpg'
# 'image (257).xml'
# 'image (258).jpg'
# 'image (258).xml'
# 'image (259).jpg'
# 'image (259).xml'
# 'image (25).jpg'
# 'image (25).xml'
# 'image (260).jpg'
# 'image (260).xml'
# 'image (261).jpg'
# 'image (261).xml'
# 'image (262).jpg'
# 'image (262).xml'
# 'image (263).jpg'
# 'image (263).xml'
# 'image (264).jpg'
# 'image (264).xml'
# 'image (265).jpg'
# 'image (265).xml'
# 'image (266).jpg'
# 'image (266).xml'
# 'image (267).jpg'
# 'image (267).xml'
# 'image (268).jpg'
# 'image (268).xml'
# 'image (269).jpg'
# 'image (269).xml'
# 'image (26).jpg'
# 'image (26).xml'
# 'image (270).jpg'
# 'image (270).xml'
# 'image (271).jpg'
# 'image (271).xml'
# 'image (272).jpg'
# 'image (272).xml'
# 'image (273).jpg'
# 'image (273).xml'
# 'image (274).jpg'
# 'image (274).xml'
# 'image (275).jpg'
# 'image (275).xml'
# 'image (276).jpg'
# 'image (276).xml'
# 'image (277).jpg'
# 'image (277).xml'
# 'image (278).jpg'
# 'image (278).xml'
# 'image (279).jpg'
# 'image (279).xml'
# 'image (27).jpg'
# 'image (27).xml'
# 'image (280).jpg'
# 'image (280).xml'
# 'image (281).jpg'
# 'image (281).xml'
# 'image (282).jpg'
# 'image (282).xml'
# 'image (283).jpg'
# 'image (283).xml'
# 'image (284).jpg'
# 'image (284).xml'
# 'image (285).jpg'
# 'image (285).xml'
# 'image (286).jpg'
# 'image (286).xml'
# 'image (287).jpg'
# 'image (287).xml'
# 'image (288).jpg'
# 'image (288).xml'
# 'image (289).jpg'
# 'image (289).xml'
# 'image (28).jpg'
# 'image (28).xml'
# 'image (290).jpg'
# 'image (290).xml'
# 'image (291).jpg'
# 'image (291).xml'
# 'image (292).jpg'
# 'image (292).xml'
# 'image (293).jpg'
# 'image (293).xml'
# 'image (294).jpg'
# 'image (294).xml'
# 'image (295).jpg'
# 'image (295).xml'
# 'image (296).jpg'
# 'image (296).xml'
# 'image (297).jpg'
# 'image (297).xml'
# 'image (298).jpg'
# 'image (298).xml'
# 'image (299).jpg'
# 'image (299).xml'
# 'image (29).jpg'
# 'image (29).xml'
# 'image (2).jpg'
# 'image (2).xml'
# 'image (300).jpg'
# 'image (300).xml'
# 'image (301).jpg'
# 'image (301).xml'
# 'image (302).jpg'
# 'image (302).xml'
# 'image (303).jpg'
# 'image (303).xml'
# 'image (304).jpg'
# 'image (304).xml'
# 'image (305).jpg'
# 'image (305).xml'
# 'image (306).jpg'
# 'image (306).xml'
# 'image (307).jpg'
# 'image (307).xml'
# 'image (308).jpg'
# 'image (308).xml'
# 'image (309).jpg'
# 'image (309).xml'
# 'image (30).jpg'
# 'image (30).xml'
# 'image (310).jpg'
# 'image (310).xml'
# 'image (311).jpg'
# 'image (311).xml'
# 'image (312).jpg'
# 'image (312).xml'
# 'image (313).jpg'
# 'image (313).xml'
# 'image (314).jpg'
# 'image (314).xml'
# 'image (315).jpg'
# 'image (315).xml'
# 'image (316).jpg'
# 'image (316).xml'
# 'image (317).jpg'
# 'image (317).xml'
# 'image (318).jpg'
# 'image (318).xml'
# 'image (319).jpg'
# 'image (319).xml'
# 'image (31).jpg'
# 'image (31).xml'
# 'image (320).jpg'
# 'image (320).xml'
# 'image (321).jpg'
# 'image (321).xml'
# 'image (322).jpg'
# 'image (322).xml'
# 'image (323).jpg'
# 'image (323).xml'
# 'image (324).jpg'
# 'image (324).xml'
# 'image (325).jpg'
# 'image (325).xml'
# 'image (326).jpg'
# 'image (326).xml'
# 'image (327).jpg'
# 'image (327).xml'
# 'image (328).jpg'
# 'image (328).xml'
# 'image (329).jpg'
# 'image (329).xml'
# 'image (32).jpg'
# 'image (32).xml'
# 'image (330).jpg'
# 'image (330).xml'
# 'image (331).jpg'
# 'image (331).xml'
# 'image (332).jpg'
# 'image (332).xml'
# 'image (333).jpg'
# 'image (333).xml'
# 'image (334).jpg'
# 'image (334).xml'
# 'image (335).jpg'
# 'image (335).xml'
# 'image (336).jpg'
# 'image (336).xml'
# 'image (337).jpg'
# 'image (337).xml'
# 'image (338).jpg'
# 'image (338).xml'
# 'image (339).jpg'
# 'image (339).xml'
# 'image (33).jpg'
# 'image (33).xml'
# 'image (340).jpg'
# 'image (340).xml'
# 'image (341).jpg'
# 'image (341).xml'
# 'image (342).jpg'
# 'image (342).xml'
# 'image (343).jpg'
# 'image (343).xml'
# 'image (344).jpg'
# 'image (344).xml'
# 'image (345).jpg'
# 'image (345).xml'
# 'image (346).jpg'
# 'image (346).xml'
# 'image (347).jpg'
# 'image (347).xml'
# 'image (348).jpg'
# 'image (348).xml'
# 'image (349).jpg'
# 'image (349).xml'
# 'image (34).jpg'
# 'image (34).xml'
# 'image (350).jpg'
# 'image (350).xml'
# 'image (351).jpg'
# 'image (351).xml'
# 'image (352).jpg'
# 'image (352).xml'
# 'image (353).jpg'
# 'image (353).xml'
# 'image (354).jpg'
# 'image (354).xml'
# 'image (355).jpg'
# 'image (355).xml'
# 'image (356).jpg'
# 'image (356).xml'
# 'image (357).jpg'
# 'image (357).xml'
# 'image (358).jpg'
# 'image (358).xml'
# 'image (359).jpg'
# 'image (359).xml'
# 'image (35).jpg'
# 'image (35).xml'
# 'image (360).jpg'
# 'image (360).xml'
# 'image (361).jpg'
# 'image (361).xml'
# 'image (362).jpg'
# 'image (362).xml'
# 'image (363).jpg'
# 'image (363).xml'
# 'image (364).jpg'
# 'image (364).xml'
# 'image (365).jpg'
# 'image (365).xml'
# 'image (366).jpg'
# 'image (366).xml'
# 'image (367).jpg'
# 'image (367).xml'
# 'image (368).jpg'
# 'image (368).xml'
# 'image (369).jpg'
# 'image (369).xml'
# 'image (36).jpg'
# 'image (36).xml'
# 'image (370).jpg'
# 'image (370).xml'
# 'image (371).jpg'
# 'image (371).xml'
# 'image (372).jpg'
# 'image (372).xml'
# 'image (373).jpg'
# 'image (373).xml'
# 'image (374).jpg'
# 'image (374).xml'
# 'image (375).jpg'
# 'image (375).xml'
# 'image (376).jpg'
# 'image (376).xml'
# 'image (377).jpg'
# 'image (377).xml'
# 'image (378).jpg'
# 'image (378).xml'
# 'image (379).jpg'
# 'image (379).xml'
# 'image (37).jpg'
# 'image (37).xml'
# 'image (380).jpg'
# 'image (380).xml'
# 'image (381).jpg'
# 'image (381).xml'
# 'image (382).jpg'
# 'image (382).xml'
# 'image (383).jpg'
# 'image (383).xml'
# 'image (384).jpg'
# 'image (384).xml'
# 'image (385).jpg'
# 'image (385).xml'
# 'image (386).jpg'
# 'image (386).xml'
# 'image (387).jpg'
# 'image (387).xml'
# 'image (388).jpg'
# 'image (388).xml'
# 'image (389).jpg'
# 'image (389).xml'
# 'image (38).jpg'
# 'image (38).xml'
# 'image (390).jpg'
# 'image (390).xml'
# 'image (391).jpg'
# 'image (391).xml'
# 'image (392).jpg'
# 'image (392).xml'
# 'image (393).jpg'
# 'image (393).xml'
# 'image (394).jpg'
# 'image (394).xml'
# 'image (395).jpg'
# 'image (395).xml'
# 'image (396).jpg'
# 'image (396).xml'
# 'image (397).jpg'
# 'image (397).xml'
# 'image (398).jpg'
# 'image (398).xml'
# 'image (399).jpg'
# 'image (399).xml'
# 'image (39).jpg'
# 'image (39).xml'
# 'image (3).jpg'
# 'image (3).xml'
# 'image (400).jpg'
# 'image (400).xml'
# 'image (401).jpg'
# 'image (401).xml'
# 'image (402).jpg'
# 'image (402).xml'
# 'image (403).jpg'
# 'image (403).xml'
# 'image (404).jpg'
# 'image (404).xml'
# 'image (405).jpg'
# 'image (405).xml'
# 'image (406).jpg'
# 'image (406).xml'
# 'image (407).jpg'
# 'image (407).xml'
# 'image (408).jpg'
# 'image (408).xml'
# 'image (409).jpg'
# 'image (409).xml'
# 'image (40).jpg'
# 'image (40).xml'
# 'image (410).jpg'
# 'image (410).xml'
# 'image (411).jpg'
# 'image (411).xml'
# 'image (412).jpg'
# 'image (412).xml'
# 'image (413).jpg'
# 'image (413).xml'
# 'image (414).jpg'
# 'image (414).xml'
# 'image (415).jpg'
# 'image (415).xml'
# 'image (416).jpg'
# 'image (416).xml'
# 'image (417).jpg'
# 'image (417).xml'
# 'image (418).jpg'
# 'image (418).xml'
# 'image (419).jpg'
# 'image (419).xml'
# 'image (41).jpg'
# 'image (41).xml'
# 'image (420).jpg'
# 'image (420).xml'
# 'image (421).jpg'
# 'image (421).xml'
# 'image (422).jpg'
# 'image (422).xml'
# 'image (423).jpg'
# 'image (423).xml'
# 'image (424).jpg'
# 'image (424).xml'
# 'image (425).jpg'
# 'image (425).xml'
# 'image (426).jpg'
# 'image (426).xml'
# 'image (427).jpg'
# 'image (427).xml'
# 'image (428).jpg'
# 'image (428).xml'
# 'image (429).jpg'
# 'image (429).xml'
# 'image (42).jpg'
# 'image (42).xml'
# 'image (430).jpg'
# 'image (430).xml'
# 'image (431).jpg'
# 'image (431).xml'
# 'image (432).jpg'
# 'image (432).xml'
# 'image (433).jpg'
# 'image (433).xml'
# 'image (434).jpg'
# 'image (434).xml'
# 'image (435).jpg'
# 'image (435).xml'
# 'image (436).jpg'
# 'image (436).xml'
# 'image (437).jpg'
# 'image (437).xml'
# 'image (438).jpg'
# 'image (438).xml'
# 'image (439).jpg'
# 'image (439).xml'
# 'image (43).jpg'
# 'image (43).xml'
# 'image (440).jpg'
# 'image (440).xml'
# 'image (441).jpg'
# 'image (441).xml'
# 'image (442).jpg'
# 'image (442).xml'
# 'image (443).jpg'
# 'image (443).xml'
# 'image (444).jpg'
# 'image (444).xml'
# 'image (445).jpg'
# 'image (445).xml'
# 'image (446).jpg'
# 'image (446).xml'
# 'image (447).jpg'
# 'image (447).xml'
# 'image (448).jpg'
# 'image (448).xml'
# 'image (449).jpg'
# 'image (449).xml'
# 'image (44).jpg'
# 'image (44).xml'
# 'image (450).jpg'
# 'image (450).xml'
# 'image (451).jpg'
# 'image (451).xml'
# 'image (452).jpg'
# 'image (452).xml'
# 'image (453).jpg'
# 'image (453).xml'
# 'image (454).jpg'
# 'image (454).xml'
# 'image (455).jpg'
# 'image (455).xml'
# 'image (456).jpg'
# 'image (456).xml'
# 'image (457).jpg'
# 'image (457).xml'
# 'image (458).jpg'
# 'image (458).xml'
# 'image (459).jpg'
# 'image (459).xml'
# 'image (45).jpg'
# 'image (45).xml'
# 'image (460).jpg'
# 'image (460).xml'
# 'image (461).jpg'
# 'image (461).xml'
# 'image (462).jpg'
# 'image (462).xml'
# 'image (463).jpg'
# 'image (463).xml'
# 'image (464).jpg'
# 'image (464).xml'
# 'image (465).jpg'
# 'image (465).xml'
# 'image (466).jpg'
# 'image (466).xml'
# 'image (467).jpg'
# 'image (467).xml'
# 'image (468).jpg'
# 'image (468).xml'
# 'image (469).jpg'
# 'image (469).xml'
# 'image (46).jpg'
# 'image (46).xml'
# 'image (470).jpg'
# 'image (470).xml'
# 'image (471).jpg'
# 'image (471).xml'
# 'image (472).jpg'
# 'image (472).xml'
# 'image (473).jpg'
# 'image (473).xml'
# 'image (474).jpg'
# 'image (474).xml'
# 'image (475).jpg'
# 'image (475).xml'
# 'image (476).jpg'
# 'image (476).xml'
# 'image (477).jpg'
# 'image (477).xml'
# 'image (478).jpg'
# 'image (478).xml'
# 'image (479).jpg'
# 'image (479).xml'
# 'image (47).jpg'
# 'image (47).xml'
# 'image (480).jpg'
# 'image (480).xml'
# 'image (481).jpg'
# 'image (481).xml'
# 'image (482).jpg'
# 'image (482).xml'
# 'image (483).jpg'
# 'image (483).xml'
# 'image (484).jpg'
# 'image (484).xml'
# 'image (485).jpg'
# 'image (485).xml'
# 'image (486).jpg'
# 'image (486).xml'
# 'image (487).jpg'
# 'image (487).xml'
# 'image (488).jpg'
# 'image (488).xml'
# 'image (489).jpg'
# 'image (489).xml'
# 'image (48).jpg'
# 'image (48).xml'
# 'image (490).jpg'
# 'image (490).xml'
# 'image (491).jpg'
# 'image (491).xml'
# 'image (492).jpg'
# 'image (492).xml'
# 'image (493).jpg'
# 'image (493).xml'
# 'image (494).jpg'
# 'image (494).xml'
# 'image (495).jpg'
# 'image (495).xml'
# 'image (496).jpg'
# 'image (496).xml'
# 'image (497).jpg'
# 'image (497).xml'
# 'image (498).jpg'
# 'image (498).xml'
# 'image (499).jpg'
# 'image (499).xml'
# 'image (49).jpg'
# 'image (49).xml'
# 'image (4).jpg'
# 'image (4).xml'
# 'image (500).jpg'
# 'image (500).xml'
# 'image (501).jpg'
# 'image (501).xml'
# 'image (502).jpg'
# 'image (502).xml'
# 'image (503).jpg'
# 'image (503).xml'
# 'image (504).jpg'
# 'image (504).xml'
# 'image (505).jpg'
# 'image (505).xml'
# 'image (506).jpg'
# 'image (506).xml'
# 'image (507).jpg'
# 'image (507).xml'
# 'image (508).jpg'
# 'image (508).xml'
# 'image (509).jpg'
# 'image (509).xml'
# 'image (50).jpg'
# 'image (50).xml'
# 'image (510).jpg'
# 'image (510).xml'
# 'image (511).jpg'
# 'image (511).xml'
# 'image (512).jpg'
# 'image (512).xml'
# 'image (513).jpg'
# 'image (513).xml'
# 'image (514).jpg'
# 'image (514).xml'
# 'image (515).jpg'
# 'image (515).xml'
# 'image (516).jpg'
# 'image (516).xml'
# 'image (517).jpg'
# 'image (517).xml'
# 'image (518).jpg'
# 'image (518).xml'
# 'image (519).jpg'
# 'image (519).xml'
# 'image (51).jpg'
# 'image (51).xml'
# 'image (520).jpg'
# 'image (520).xml'
# 'image (521).jpg'
# 'image (521).xml'
# 'image (522).jpg'
# 'image (522).xml'
# 'image (523).jpg'
# 'image (523).xml'
# 'image (524).jpg'
# 'image (524).xml'
# 'image (525).jpg'
# 'image (525).xml'
# 'image (526).jpg'
# 'image (526).xml'
# 'image (527).jpg'
# 'image (527).xml'
# 'image (528).jpg'
# 'image (528).xml'
# 'image (529).jpg'
# 'image (529).xml'
# 'image (52).jpg'
# 'image (52).xml'
# 'image (530).jpg'
# 'image (530).xml'
# 'image (531).jpg'
# 'image (531).xml'
# 'image (532).jpg'
# 'image (532).xml'
# 'image (533).jpg'
# 'image (533).xml'
# 'image (534).jpg'
# 'image (534).xml'
# 'image (535).jpg'
# 'image (535).xml'
# 'image (536).jpg'
# 'image (536).xml'
# 'image (537).jpg'
# 'image (537).xml'
# 'image (538).jpg'
# 'image (538).xml'
# 'image (539).jpg'
# 'image (539).xml'
# 'image (53).jpg'
# 'image (53).xml'
# 'image (540).jpg'
# 'image (540).xml'
# 'image (541).jpg'
# 'image (541).xml'
# 'image (542).jpg'
# 'image (542).xml'
# 'image (543).jpg'
# 'image (543).xml'
# 'image (544).jpg'
# 'image (544).xml'
# 'image (545).jpg'
# 'image (545).xml'
# 'image (546).jpg'
# 'image (546).xml'
# 'image (547).jpg'
# 'image (547).xml'
# 'image (548).jpg'
# 'image (548).xml'
# 'image (549).jpg'
# 'image (549).xml'
# 'image (54).jpg'
# 'image (54).xml'
# 'image (550).jpg'
# 'image (550).xml'
# 'image (551).jpg'
# 'image (551).xml'
# 'image (552).jpg'
# 'image (552).xml'
# 'image (553).jpg'
# 'image (553).xml'
# 'image (554).jpg'
# 'image (554).xml'
# 'image (555).jpg'
# 'image (555).xml'
# 'image (556).jpg'
# 'image (556).xml'
# 'image (557).jpg'
# 'image (557).xml'
# 'image (558).jpg'
# 'image (558).xml'
# 'image (559).jpg'
# 'image (559).xml'
# 'image (55).jpg'
# 'image (55).xml'
# 'image (560).jpg'
# 'image (560).xml'
# 'image (561).jpg'
# 'image (561).xml'
# 'image (562).jpg'
# 'image (562).xml'
# 'image (563).jpg'
# 'image (563).xml'
# 'image (564).jpg'
# 'image (564).xml'
# 'image (565).jpg'
# 'image (565).xml'
# 'image (566).jpg'
# 'image (566).xml'
# 'image (567).jpg'
# 'image (567).xml'
# 'image (568).jpg'
# 'image (568).xml'
# 'image (569).jpg'
# 'image (569).xml'
# 'image (56).jpg'
# 'image (56).xml'
# 'image (570).jpg'
# 'image (570).xml'
# 'image (571).jpg'
# 'image (571).xml'
# 'image (572).jpg'
# 'image (572).xml'
# 'image (573).jpg'
# 'image (573).xml'
# 'image (574).jpg'
# 'image (574).xml'
# 'image (575).jpg'
# 'image (575).xml'
# 'image (576).jpg'
# 'image (576).xml'
# 'image (577).jpg'
# 'image (577).xml'
# 'image (578).jpg'
# 'image (578).xml'
# 'image (579).jpg'
# 'image (579).xml'
# 'image (57).jpg'
# 'image (57).xml'
# 'image (580).jpg'
# 'image (580).xml'
# 'image (581).jpg'
# 'image (581).xml'
# 'image (582).jpg'
# 'image (582).xml'
# 'image (583).jpg'
# 'image (583).xml'
# 'image (584).jpg'
# 'image (584).xml'
# 'image (585).jpg'
# 'image (585).xml'
# 'image (586).jpg'
# 'image (586).xml'
# 'image (587).jpg'
# 'image (587).xml'
# 'image (588).jpg'
# 'image (588).xml'
# 'image (589).jpg'
# 'image (589).xml'
# 'image (58).jpg'
# 'image (58).xml'
# 'image (590).jpg'
# 'image (590).xml'
# 'image (591).jpg'
# 'image (591).xml'
# 'image (592).jpg'
# 'image (592).xml'
# 'image (593).jpg'
# 'image (593).xml'
# 'image (594).jpg'
# 'image (594).xml'
# 'image (595).jpg'
# 'image (595).xml'
# 'image (596).jpg'
# 'image (596).xml'
# 'image (597).jpg'
# 'image (597).xml'
# 'image (598).jpg'
# 'image (598).xml'
# 'image (599).jpg'
# 'image (599).xml'
# 'image (59).jpg'
# 'image (59).xml'
# 'image (5).jpg'
# 'image (5).xml'
# 'image (600).jpg'
# 'image (600).xml'
# 'image (601).jpg'
# 'image (601).xml'
# 'image (602).jpg'
# 'image (602).xml'
# 'image (603).jpg'
# 'image (603).xml'
# 'image (604).jpg'
# 'image (604).xml'
# 'image (605).jpg'
# 'image (605).xml'
# 'image (606).jpg'
# 'image (606).xml'
# 'image (607).jpg'
# 'image (607).xml'
# 'image (608).jpg'
# 'image (608).xml'
# 'image (609).jpg'
# 'image (609).xml'
# 'image (60).jpg'
# 'image (60).xml'
# 'image (610).jpg'
# 'image (610).xml'
# 'image (611).jpg'
# 'image (611).xml'
# 'image (612).jpg'
# 'image (612).xml'
# 'image (613).jpg'
# 'image (613).xml'
# 'image (614).jpg'
# 'image (614).xml'
# 'image (615).jpg'
# 'image (615).xml'
# 'image (616).jpg'
# 'image (616).xml'
# 'image (617).jpg'
# 'image (617).xml'
# 'image (618).jpg'
# 'image (618).xml'
# 'image (619).jpg'
# 'image (619).xml'
# 'image (61).jpg'
# 'image (61).xml'
# 'image (620).jpg'
# 'image (620).xml'
# 'image (621).jpg'
# 'image (621).xml'
# 'image (622).jpg'
# 'image (622).xml'
# 'image (623).jpg'
# 'image (623).xml'
# 'image (624).jpg'
# 'image (624).xml'
# 'image (625).jpg'
# 'image (625).xml'
# 'image (626).jpg'
# 'image (626).xml'
# 'image (627).jpg'
# 'image (627).xml'
# 'image (628).jpg'
# 'image (628).xml'
# 'image (629).jpg'
# 'image (629).xml'
# 'image (62).jpg'
# 'image (62).xml'
# 'image (630).jpg'
# 'image (630).xml'
# 'image (631).jpg'
# 'image (631).xml'
# 'image (632).jpg'
# 'image (632).xml'
# 'image (633).jpg'
# 'image (633).xml'
# 'image (634).jpg'
# 'image (634).xml'
# 'image (635).jpg'
# 'image (635).xml'
# 'image (636).jpg'
# 'image (636).xml'
# 'image (637).jpg'
# 'image (637).xml'
# 'image (638).jpg'
# 'image (638).xml'
# 'image (639).jpg'
# 'image (639).xml'
# 'image (63).jpg'
# 'image (63).xml'
# 'image (640).jpg'
# 'image (640).xml'
# 'image (641).jpg'
# 'image (641).xml'
# 'image (642).jpg'
# 'image (642).xml'
# 'image (643).jpg'
# 'image (643).xml'
# 'image (644).jpg'
# 'image (644).xml'
# 'image (645).jpg'
# 'image (645).xml'
# 'image (646).jpg'
# 'image (646).xml'
# 'image (647).jpg'
# 'image (647).xml'
# 'image (648).jpg'
# 'image (648).xml'
# 'image (649).jpg'
# 'image (649).xml'
# 'image (64).jpg'
# 'image (64).xml'
# 'image (650).jpg'
# 'image (650).xml'
# 'image (651).jpg'
# 'image (651).xml'
# 'image (652).jpg'
# 'image (652).xml'
# 'image (653).jpg'
# 'image (653).xml'
# 'image (654).jpg'
# 'image (654).xml'
# 'image (655).jpg'
# 'image (655).xml'
# 'image (656).jpg'
# 'image (656).xml'
# 'image (657).jpg'
# 'image (657).xml'
# 'image (658).jpg'
# 'image (658).xml'
# 'image (659).jpg'
# 'image (659).xml'
# 'image (65).jpg'
# 'image (65).xml'
# 'image (660).jpg'
# 'image (660).xml'
# 'image (661).jpg'
# 'image (661).xml'
# 'image (662).jpg'
# 'image (662).xml'
# 'image (663).jpg'
# 'image (663).xml'
# 'image (664).jpg'
# 'image (664).xml'
# 'image (665).jpg'
# 'image (665).xml'
# 'image (666).jpg'
# 'image (666).xml'
# 'image (667).jpg'
# 'image (667).xml'
# 'image (668).jpg'
# 'image (668).xml'
# 'image (669).jpg'
# 'image (669).xml'
# 'image (66).jpg'
# 'image (66).xml'
# 'image (670).jpg'
# 'image (670).xml'
# 'image (671).jpg'
# 'image (671).xml'
# 'image (672).jpg'
# 'image (672).xml'
# 'image (673).jpg'
# 'image (673).xml'
# 'image (674).jpg'
# 'image (674).xml'
# 'image (675).jpg'
# 'image (675).xml'
# 'image (676).jpg'
# 'image (676).xml'
# 'image (677).jpg'
# 'image (677).xml'
# 'image (678).jpg'
# 'image (678).xml'
# 'image (679).jpg'
# 'image (679).xml'
# 'image (67).jpg'
# 'image (67).xml'
# 'image (680).jpg'
# 'image (680).xml'
# 'image (681).jpg'
# 'image (681).xml'
# 'image (682).jpg'
# 'image (682).xml'
# 'image (683).jpg'
# 'image (683).xml'
# 'image (684).jpg'
# 'image (684).xml'
# 'image (685).jpg'
# 'image (685).xml'
# 'image (686).jpg'
# 'image (686).xml'
# 'image (687).jpg'
# 'image (687).xml'
# 'image (688).jpg'
# 'image (688).xml'
# 'image (689).jpg'
# 'image (689).xml'
# 'image (68).jpg'
# 'image (68).xml'
# 'image (690).jpg'
# 'image (690).xml'
# 'image (691).jpg'
# 'image (691).xml'
# 'image (692).jpg'
# 'image (692).xml'
# 'image (693).jpg'
# 'image (693).xml'
# 'image (694).jpg'
# 'image (694).xml'
# 'image (695).jpg'
# 'image (695).xml'
# 'image (696).jpg'
# 'image (696).xml'
# 'image (697).jpg'
# 'image (697).xml'
# 'image (698).jpg'
# 'image (698).xml'
# 'image (699).jpg'
# 'image (699).xml'
# 'image (69).jpg'
# 'image (69).xml'
# 'image (6).jpg'
# 'image (6).xml'
# 'image (700).jpg'
# 'image (700).xml'
# 'image (701).jpg'
# 'image (701).xml'
# 'image (702).jpg'
# 'image (702).xml'
# 'image (703).jpg'
# 'image (703).xml'
# 'image (704).jpg'
# 'image (704).xml'
# 'image (705).jpg'
# 'image (705).xml'
# 'image (706).jpg'
# 'image (706).xml'
# 'image (707).jpg'
# 'image (707).xml'
# 'image (708).jpg'
# 'image (708).xml'
# 'image (709).jpg'
# 'image (709).xml'
# 'image (70).jpg'
# 'image (70).xml'
# 'image (710).jpg'
# 'image (710).xml'
# 'image (711).jpg'
# 'image (711).xml'
# 'image (712).jpg'
# 'image (712).xml'
# 'image (713).jpg'
# 'image (713).xml'
# 'image (714).jpg'
# 'image (714).xml'
# 'image (715).jpg'
# 'image (715).xml'
# 'image (716).jpg'
# 'image (716).xml'
# 'image (717).jpg'
# 'image (717).xml'
# 'image (718).jpg'
# 'image (718).xml'
# 'image (719).jpg'
# 'image (719).xml'
# 'image (71).jpg'
# 'image (71).xml'
# 'image (720).jpg'
# 'image (720).xml'
# 'image (721).jpg'
# 'image (721).xml'
# 'image (722).jpg'
# 'image (722).xml'
# 'image (723).jpg'
# 'image (723).xml'
# 'image (724).jpg'
# 'image (724).xml'
# 'image (725).jpg'
# 'image (725).xml'
# 'image (726).jpg'
# 'image (726).xml'
# 'image (727).jpg'
# 'image (727).xml'
# 'image (728).jpg'
# 'image (728).xml'
# 'image (729).jpg'
# 'image (729).xml'
# 'image (72).jpg'
# 'image (72).xml'
# 'image (730).jpg'
# 'image (730).xml'
# 'image (731).jpg'
# 'image (731).xml'
# 'image (732).jpg'
# 'image (732).xml'
# 'image (733).jpg'
# 'image (733).xml'
# 'image (734).jpg'
# 'image (734).xml'
# 'image (735).jpg'
# 'image (735).xml'
# 'image (736).jpg'
# 'image (736).xml'
# 'image (737).jpg'
# 'image (737).xml'
# 'image (738).jpg'
# 'image (738).xml'
# 'image (739).jpg'
# 'image (739).xml'
# 'image (73).jpg'
# 'image (73).xml'
# 'image (740).jpg'
# 'image (740).xml'
# 'image (741).jpg'
# 'image (741).xml'
# 'image (742).jpg'
# 'image (742).xml'
# 'image (743).jpg'
# 'image (743).xml'
# 'image (744).jpg'
# 'image (744).xml'
# 'image (745).jpg'
# 'image (745).xml'
# 'image (746).jpg'
# 'image (746).xml'
# 'image (747).jpg'
# 'image (747).xml'
# 'image (748).jpg'
# 'image (748).xml'
# 'image (749).jpg'
# 'image (749).xml'
# 'image (74).jpg'
# 'image (74).xml'
# 'image (750).jpg'
# 'image (750).xml'
# 'image (751).jpg'
# 'image (751).xml'
# 'image (752).jpg'
# 'image (752).xml'
# 'image (753).jpg'
# 'image (753).xml'
# 'image (754).jpg'
# 'image (754).xml'
# 'image (755).jpg'
# 'image (755).xml'
# 'image (756).jpg'
# 'image (756).xml'
# 'image (757).jpg'
# 'image (757).xml'
# 'image (758).jpg'
# 'image (758).xml'
# 'image (759).jpg'
# 'image (759).xml'
# 'image (75).jpg'
# 'image (75).xml'
# 'image (760).jpg'
# 'image (760).xml'
# 'image (761).jpg'
# 'image (761).xml'
# 'image (762).jpg'
# 'image (762).xml'
# 'image (763).jpg'
# 'image (763).xml'
# 'image (764).jpg'
# 'image (764).xml'
# 'image (765).jpg'
# 'image (765).xml'
# 'image (766).jpg'
# 'image (766).xml'
# 'image (767).jpg'
# 'image (767).xml'
# 'image (768).jpg'
# 'image (768).xml'
# 'image (769).jpg'
# 'image (769).xml'
# 'image (76).jpg'
# 'image (76).xml'
# 'image (770).jpg'
# 'image (770).xml'
# 'image (771).jpg'
# 'image (771).xml'
# 'image (772).jpg'
# 'image (772).xml'
# 'image (773).jpg'
# 'image (773).xml'
# 'image (774).jpg'
# 'image (774).xml'
# 'image (775).jpg'
# 'image (775).xml'
# 'image (776).jpg'
# 'image (776).xml'
# 'image (777).jpg'
# 'image (777).xml'
# 'image (778).jpg'
# 'image (778).xml'
# 'image (779).jpg'
# 'image (779).xml'
# 'image (77).jpg'
# 'image (77).xml'
# 'image (780).jpg'
# 'image (780).xml'
# 'image (781).jpg'
# 'image (781).xml'
# 'image (782).jpg'
# 'image (782).xml'
# 'image (783).jpg'
# 'image (783).xml'
# 'image (784).jpg'
# 'image (784).xml'
# 'image (785).jpg'
# 'image (785).xml'
# 'image (786).jpg'
# 'image (786).xml'
# 'image (787).jpg'
# 'image (787).xml'
# 'image (788).jpg'
# 'image (788).xml'
# 'image (789).jpg'
# 'image (789).xml'
# 'image (78).jpg'
# 'image (78).xml'
# 'image (790).jpg'
# 'image (790).xml'
# 'image (791).jpg'
# 'image (791).xml'
# 'image (792).jpg'
# 'image (792).xml'
# 'image (793).jpg'
# 'image (793).xml'
# 'image (794).jpg'
# 'image (794).xml'
# 'image (795).jpg'
# 'image (795).xml'
# 'image (796).jpg'
# 'image (796).xml'
# 'image (797).jpg'
# 'image (797).xml'
# 'image (798).jpg'
# 'image (798).xml'
# 'image (799).jpg'
# 'image (799).xml'
# 'image (79).jpg'
# 'image (79).xml'
# 'image (7).jpg'
# 'image (7).xml'
# 'image (800).jpg'
# 'image (800).xml'
# 'image (801).jpg'
# 'image (801).xml'
# 'image (802).jpg'
# 'image (802).xml'
# 'image (803).jpg'
# 'image (803).xml'
# 'image (804).jpg'
# 'image (804).xml'
# 'image (805).jpg'
# 'image (805).xml'
# 'image (806).jpg'
# 'image (806).xml'
# 'image (807).jpg'
# 'image (807).xml'
# 'image (808).jpg'
# 'image (808).xml'
# 'image (809).jpg'
# 'image (809).xml'
# 'image (80).jpg'
# 'image (80).xml'
# 'image (810).jpg'
# 'image (810).xml'
# 'image (811).jpg'
# 'image (811).xml'
# 'image (812).jpg'
# 'image (812).xml'
# 'image (813).jpg'
# 'image (813).xml'
# 'image (814).jpg'
# 'image (814).xml'
# 'image (815).jpg'
# 'image (815).xml'
# 'image (816).jpg'
# 'image (816).xml'
# 'image (817).jpg'
# 'image (817).xml'
# 'image (818).jpg'
# 'image (818).xml'
# 'image (819).jpg'
# 'image (819).xml'
# 'image (81).jpg'
# 'image (81).xml'
# 'image (820).jpg'
# 'image (820).xml'
# 'image (821).jpg'
# 'image (821).xml'
# 'image (822).jpg'
# 'image (822).xml'
# 'image (823).jpg'
# 'image (823).xml'
# 'image (824).jpg'
# 'image (824).xml'
# 'image (825).jpg'
# 'image (825).xml'
# 'image (826).jpg'
# 'image (826).xml'
# 'image (827).jpg'
# 'image (827).xml'
# 'image (828).jpg'
# 'image (828).xml'
# 'image (829).jpg'
# 'image (829).xml'
# 'image (82).jpg'
# 'image (82).xml'
# 'image (830).jpg'
# 'image (830).xml'
# 'image (831).jpg'
# 'image (831).xml'
# 'image (832).jpg'
# 'image (832).xml'
# 'image (833).jpg'
# 'image (833).xml'
# 'image (834).jpg'
# 'image (834).xml'
# 'image (835).jpg'
# 'image (835).xml'
# 'image (836).jpg'
# 'image (836).xml'
# 'image (837).jpg'
# 'image (837).xml'
# 'image (838).jpg'
# 'image (838).xml'
# 'image (839).jpg'
# 'image (839).xml'
# 'image (83).jpg'
# 'image (83).xml'
# 'image (840).jpg'
# 'image (840).xml'
# 'image (841).jpg'
# 'image (841).xml'
# 'image (842).jpg'
# 'image (842).xml'
# 'image (843).jpg'
# 'image (843).xml'
# 'image (844).jpg'
# 'image (844).xml'
# 'image (845).jpg'
# 'image (845).xml'
# 'image (846).jpg'
# 'image (846).xml'
# 'image (847).jpg'
# 'image (847).xml'
# 'image (848).jpg'
# 'image (848).xml'
# 'image (849).jpg'
# 'image (849).xml'
# 'image (84).jpg'
# 'image (84).xml'
# 'image (850).jpg'
# 'image (850).xml'
# 'image (851).jpg'
# 'image (851).xml'
# 'image (852).jpg'
# 'image (852).xml'
# 'image (853).jpg'
# 'image (853).xml'
# 'image (854).jpg'
# 'image (854).xml'
# 'image (855).jpg'
# 'image (855).xml'
# 'image (856).jpg'
# 'image (856).xml'
# 'image (857).jpg'
# 'image (857).xml'
# 'image (858).jpg'
# 'image (858).xml'
# 'image (859).jpg'
# 'image (859).xml'
# 'image (85).jpg'
# 'image (85).xml'
# 'image (860).jpg'
# 'image (860).xml'
# 'image (861).jpg'
# 'image (861).xml'
# 'image (862).jpg'
# 'image (862).xml'
# 'image (863).jpg'
# 'image (863).xml'
# 'image (864).jpg'
# 'image (864).xml'
# 'image (865).jpg'
# 'image (865).xml'
# 'image (866).jpg'
# 'image (866).xml'
# 'image (867).jpg'
# 'image (867).xml'
# 'image (868).jpg'
# 'image (868).xml'
# 'image (869).jpg'
# 'image (869).xml'
# 'image (86).jpg'
# 'image (86).xml'
# 'image (870).jpg'
# 'image (870).xml'
# 'image (871).jpg'
# 'image (871).xml'
# 'image (872).jpg'
# 'image (872).xml'
# 'image (873).jpg'
# 'image (873).xml'
# 'image (874).jpg'
# 'image (874).xml'
# 'image (875).jpg'
# 'image (875).xml'
# 'image (876).jpg'
# 'image (876).xml'
# 'image (877).jpg'
# 'image (877).xml'
# 'image (878).jpg'
# 'image (878).xml'
# 'image (879).jpg'
# 'image (879).xml'
# 'image (87).jpg'
# 'image (87).xml'
# 'image (880).jpg'
# 'image (880).xml'
# 'image (881).jpg'
# 'image (881).xml'
# 'image (882).jpg'
# 'image (882).xml'
# 'image (883).jpg'
# 'image (883).xml'
# 'image (884).jpg'
# 'image (884).xml'
# 'image (885).jpg'
# 'image (885).xml'
# 'image (886).jpg'
# 'image (886).xml'
# 'image (887).jpg'
# 'image (887).xml'
# 'image (888).jpg'
# 'image (888).xml'
# 'image (889).jpg'
# 'image (889).xml'
# 'image (88).jpg'
# 'image (88).xml'
# 'image (890).jpg'
# 'image (890).xml'
# 'image (891).jpg'
# 'image (891).xml'
# 'image (892).jpg'
# 'image (892).xml'
# 'image (893).jpg'
# 'image (893).xml'
# 'image (894).jpg'
# 'image (894).xml'
# 'image (895).jpg'
# 'image (895).xml'
# 'image (896).jpg'
# 'image (896).xml'
# 'image (897).jpg'
# 'image (897).xml'
# 'image (898).jpg'
# 'image (898).xml'
# 'image (899).jpg'
# 'image (899).xml'
# 'image (89).jpg'
# 'image (89).xml'
# 'image (8).jpg'
# 'image (8).xml'
# 'image (900).jpg'
# 'image (900).xml'
# 'image (901).jpg'
# 'image (901).xml'
# 'image (902).jpg'
# 'image (902).xml'
# 'image (903).jpg'
# 'image (903).xml'
# 'image (904).jpg'
# 'image (904).xml'
# 'image (905).jpg'
# 'image (905).xml'
# 'image (906).jpg'
# 'image (906).xml'
# 'image (907).jpg'
# 'image (907).xml'
# 'image (908).jpg'
# 'image (908).xml'
# 'image (909).jpg'
# 'image (909).xml'
# 'image (90).jpg'
# 'image (90).xml'
# 'image (910).jpg'
# 'image (910).xml'
# 'image (911).jpg'
# 'image (911).xml'
# 'image (912).jpg'
# 'image (912).xml'
# 'image (913).jpg'
# 'image (913).xml'
# 'image (914).jpg'
# 'image (914).xml'
# 'image (915).jpg'
# 'image (915).xml'
# 'image (916).jpg'
# 'image (916).xml'
# 'image (917).jpg'
# 'image (917).xml'
# 'image (918).jpg'
# 'image (918).xml'
# 'image (919).jpg'
# 'image (919).xml'
# 'image (91).jpg'
# 'image (91).xml'
# 'image (920).jpg'
# 'image (920).xml'
# 'image (921).jpg'
# 'image (921).xml'
# 'image (922).jpg'
# 'image (922).xml'
# 'image (923).jpg'
# 'image (923).xml'
# 'image (924).jpg'
# 'image (924).xml'
# 'image (925).jpg'
# 'image (925).xml'
# 'image (926).jpg'
# 'image (926).xml'
# 'image (927).jpg'
# 'image (927).xml'
# 'image (928).jpg'
# 'image (928).xml'
# 'image (929).jpg'
# 'image (929).xml'
# 'image (92).jpg'
# 'image (92).xml'
# 'image (930).jpg'
# 'image (930).xml'
# 'image (931).jpg'
# 'image (931).xml'
# 'image (932).jpg'
# 'image (932).xml'
# 'image (933).jpg'
# 'image (933).xml'
# 'image (934).jpg'
# 'image (934).xml'
# 'image (935).jpg'
# 'image (935).xml'
# 'image (936).jpg'
# 'image (936).xml'
# 'image (937).jpg'
# 'image (937).xml'
# 'image (938).jpg'
# 'image (938).xml'
# 'image (939).jpg'
# 'image (939).xml'
# 'image (93).jpg'
# 'image (93).xml'
# 'image (940).jpg'
# 'image (940).xml'
# 'image (941).jpg'
# 'image (941).xml'
# 'image (942).jpg'
# 'image (942).xml'
# 'image (943).jpg'
# 'image (943).xml'
# 'image (944).jpg'
# 'image (944).xml'
# 'image (945).jpg'
# 'image (945).xml'
# 'image (94).jpg'
# 'image (94).xml'
# 'image (95).jpg'
# 'image (95).xml'
# 'image (96).jpg'
# 'image (96).xml'
# 'image (97).jpg'
# 'image (97).xml'
# 'image (98).jpg'
# 'image (98).xml'
# 'image (99).jpg'
# 'image (99).xml'
# 'image (9).jpg'
# 'image (9).xml'
# 'images (10).jpg'
# 'images (10).xml'
# 'images (11).jpg'
# 'images (11).xml'
# 'images (13).jpg'
# 'images (13).xml'
# 'images (14).jpg'
# 'images (14).xml'
# 'images (15).jpg'
# 'images (15).xml'
# 'images (16).jpg'
# 'images (16).xml'
# 'images (17).jpg'
# 'images (17).xml'
# 'images (18).jpg'
# 'images (18).xml'
# 'images (19).jpg'
# 'images (19).xml'
# 'images (20).jpg'
# 'images (20).xml'
# 'images (21).jpg'
# 'images (21).xml'
# 'images (29).jpg'
# 'images (29).xml'
# 'images (30).jpg'
# 'images (30).xml'
# 'images (31).jpg'
# 'images (31).xml'
# 'images (32).jpg'
# 'images (32).xml'
# 'images (33).jpg'
# 'images (33).xml'
# 'images (34).jpg'
# 'images (34).xml'
# 'images (35).jpg'
# 'images (35).xml'
# 'images (36).jpg'
# 'images (36).xml'
# 'images (37).jpg'
# 'images (37).xml'
# 'images (38).jpg'
# 'images (38).xml'
# 'images (39).jpg'
# 'images (39).xml'
# 'images (3).jpg'
# 'images (3).xml'
# 'images (40).jpg'
# 'images (40).xml'
# 'images (41).jpg'
# 'images (41).xml'
# 'images (42).jpg'
# 'images (42).xml'
# 'images (43).jpg'
# 'images (43).xml'
# 'images (44).jpg'
# 'images (44).xml'
# 'images (45).jpg'
# 'images (45).xml'
# 'images (46).jpg'
# 'images (46).xml'
# 'images (47).jpg'
# 'images (47).xml'
# 'images (48).jpg'
# 'images (48).xml'
# 'images (49).jpg'
# 'images (49).xml'
# 'images (50).jpg'
# 'images (50).xml'
# 'images (51).jpg'
# 'images (51).xml'
# 'images (52).jpg'
# 'images (52).xml'
# 'images (5).jpg'
# 'images (5).xml'
# 'images (6).jpg'
# 'images (6).xml'
# 'images (8).jpg'
# 'images (8).xml'
# 'images (9).jpg'
# 'images (9).xml'
#  IMG-20201221-WA0023.jpg
#  IMG-20201221-WA0023.xml
#  inline_image_preview.jpg
#  inline_image_preview.xml
#  itzy.all.in.us_185811769_824585428407603_703025045808869964_n.jpg
#  itzy.all.in.us_185811769_824585428407603_703025045808869964_n.xml
#  itzy.all.in.us_192451335_200558191914508_2335878010331548651_n.jpg
#  itzy.all.in.us_192451335_200558191914508_2335878010331548651_n.xml
#  itzy.all.in.us_192711099_193313259313287_5065584756365681020_n.jpg
#  itzy.all.in.us_192711099_193313259313287_5065584756365681020_n.xml
#  itzy.all.in.us_192830426_1123515584826435_684774574316350226_n.jpg
#  itzy.all.in.us_192830426_1123515584826435_684774574316350226_n.xml
#  jalur-pedestrian-sisingamangaraja-jakarta-400x250.jpg
#  jalur-pedestrian-sisingamangaraja-jakarta-400x250.xml
#  orang-terkaya.jpg
#  orang-terkaya.xml
#  pedestrian-friendly-streets_0.jpg
#  pedestrian-friendly-streets_0.xml
#  pedestrian-jadi-tempat-mangkal-ojol-kaum-difabel-masih-anak-tiri-YdIDkfHNHf.jpg
#  pedestrian-jadi-tempat-mangkal-ojol-kaum-difabel-masih-anak-tiri-YdIDkfHNHf.xml
# 'pedestrians.mp4 - VLC media player 5_30_2021 1_56_56 AM.png'
# 'pedestrians.mp4 - VLC media player 5_30_2021 1_56_56 AM.xml'
# 'pedestrians.mp4 - VLC media player 5_30_2021 1_56_59 AM.png'
# 'pedestrians.mp4 - VLC media player 5_30_2021 1_56_59 AM.xml'
#  pembanguan-trotoar-untun-pedesttria-e1567484536957.jpg
#  pembanguan-trotoar-untun-pedesttria-e1567484536957.xml
#  prescott-horn-h1czsSeoImU-unsplash.jpg
#  prescott-horn-h1czsSeoImU-unsplash.xml
#  style-redhead-girl-sitting-on-260nw-134009834.jpg
#  style-redhead-girl-sitting-on-260nw-134009834.xml
#  zebra-cross.jpg
#  zebra-cross.xml

# %% [markdown]
# # Install Tensorflow Object Detection API
#
# Clone TF models which contains the Object Detection API; also install the required dependencies

# %%
# %%capture
# %cd /content
# !git clone --quiet https://github.com/tensorflow/models.git
# %cd /content/models/
# !git checkout 58d19c67e1d30d905dd5c6e5092348658fed80af
# !apt-get install -qq protobuf-compiler python-pil python-lxml python-tk
# !pip install -q Cython contextlib2 pillow lxml matplotlib
# !pip install -q pycocotools
# %cd /content/models/research
# !protoc object_detection/protos/*.proto --python_out=.
# Out:
# /content
# /content/models
# Note: checking out '58d19c67e1d30d905dd5c6e5092348658fed80af'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by performing another checkout.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -b with the checkout command again. Example:
#
#   git checkout -b <new-branch-name>
#
# HEAD is now at 58d19c67 Internal change
# E: Failed to fetch http://security.ubuntu.com/ubuntu/pool/main/p/pillow/python-pil_5.1.0-1ubuntu0.5_amd64.deb  404  Not Found [IP: 91.189.88.142 80]
# E: Unable to fetch some archives, maybe run apt-get update or try with --fix-missing?
# /content/models/research
# object_detection/protos/input_reader.proto: warning: Import object_detection/protos/image_resizer.proto but not used.

# %%
# !pip install tf_slim
# Out:
# Requirement already satisfied: tf_slim in /usr/local/lib/python3.7/dist-packages (1.1.0)
# Requirement already satisfied: absl-py>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from tf_slim) (0.12.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from absl-py>=0.2.2->tf_slim) (1.15.0)

# %% [markdown]
# # # set the location to the path contain tensorflow object detection API that already downloaded

# %%
import os
os.environ['PYTHONPATH'] += ':/content/models/research/:/content/models/research/slim/'
# !python object_detection/builders/model_builder_test.py
# Out:
# 2021-05-30 15:30:57.336576: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0

# %% [markdown]
# ## Prepare `tfrecord` files

# %%
# %%capture
# %cd {repo_dir_path}
print(repo_dir_path)

# %% [markdown]
# # # Turn dataset folder into csv file

# %%
# !python xml_to_csv.py -i data/images/train -o data/annotations/train_labels.csv -l data/annotations
# !python xml_to_csv.py -i data/images/test -o data/annotations/test_labels.csv

# Set the paths
test_record_fname = '/content/object_detection_demo_flow/data/annotations/test.record'
train_record_fname = '/content/object_detection_demo_flow/data/annotations/train.record'
label_map_pbtxt_fname = '/content/object_detection_demo_flow/data/annotations/label_map.pbtxt'
# Out:
# Successfully converted xml to csv.
# Generate `data/annotations/label_map.pbtxt`
# Successfully converted xml to csv.

# %% [markdown]
# # Run genereate_tfrecord to make tfrecord file that contain all labels and dataset name

# %%
# !python generate_tfrecord.py --csv_input=data/annotations/train_labels.csv --output_path=data/annotations/train.record --img_path=data/images/train --label_map data/annotations/label_map.pbtxt
# !python generate_tfrecord.py --csv_input=data/annotations/test_labels.csv --output_path=data/annotations/test.record --img_path=data/images/test --label_map data/annotations/label_map.pbtxt
# Out:
# 2021-05-30 16:18:28.451603: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# Successfully created the TFRecords: /content/object_detection_demo_flow/data/annotations/train.record
# a
# 2021-05-30 16:18:31.963272: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# Successfully created the TFRecords: /content/object_detection_demo_flow/data/annotations/test.record

# %%
# !ls /content/object_detection_demo_flow/data/annotations/
# Out:
# label_map.pbtxt  test_labels.csv  train_labels.csv

# %% [markdown]
# ## Download pretrained model

# %%
# %cd /content/models/research

import os
import shutil
import glob
import urllib.request
import tarfile
##Set location of pretrained model
MODEL_FILE = 'sd_mobilenet_v2_320x320_coco17_tpu-8.tar.gz'
DOWNLOAD_BASE = 'http://download.tensorflow.org/models/object_detection/tf2/20200711/ssd_mobilenet_v2_320x320_coco17_tpu-8.tar.gz'
DEST_DIR = '/content/models/research/pretrained_model'

if not (os.path.exists(MODEL_FILE)):
    urllib.request.urlretrieve(DOWNLOAD_BASE , MODEL_FILE)

tar = tarfile.open(MODEL_FILE)
tar.extractall()
tar.close()

os.remove(MODEL_FILE)
if (os.path.exists(DEST_DIR)):
    shutil.rmtree(DEST_DIR)
os.rename("ssd_mobilenet_v2_320x320_coco17_tpu-8", DEST_DIR)
# !echo {DEST_DIR}
# !ls -alh {DEST_DIR}
# Out:
# /content/models/research
# sd_mobilenet_v2_320x320_coco17_tpu-8
# /content/models/research/pretrained_model
# total 24K
# drwxr-x---  4 345018 89939 4.0K Jul 11  2020 .
# drwxr-xr-x 63 root   root  4.0K May 30 16:38 ..
# drwxr-x---  2 345018 89939 4.0K Jul 10  2020 checkpoint
# -rw-r-----  1 345018 89939 4.4K Jul 11  2020 pipeline.config
# drwxr-x---  3 345018 89939 4.0K Jul 10  2020 saved_model

# %%
#TF pretrained model checkpoint
fine_tune_checkpoint = os.path.join(DEST_DIR, "model.ckpt")
fine_tune_checkpoint
# Out:
# '/content/models/research/pretrained_model/model.ckpt'

# %% [markdown]
# ## Configuring a Training Pipeline

# %%
import os
pipeline_fname = os.path.join('/content/models/research/object_detection/samples/configs/', pipeline_file)

assert os.path.isfile(pipeline_fname), '`{}` not exist'.format(pipeline_fname)
def get_num_classes(pbtxt_fname):
    from object_detection.utils import label_map_util
    label_map = label_map_util.load_labelmap(pbtxt_fname)
    categories = label_map_util.convert_label_map_to_categories(
        label_map, max_num_classes=90, use_display_name=True)
    category_index = label_map_util.create_category_index(categories)
    return len(category_index.keys())

# %%
import re
iou_threshold = 0.50
num_classes = get_num_classes(label_map_pbtxt_fname)
with open(pipeline_fname) as f:
    s = f.read()
with open(pipeline_fname, 'w') as f:
    
    # fine_tune_checkpoint
    s = re.sub('fine_tune_checkpoint: ".*?"',
               'fine_tune_checkpoint: "{}"'.format(fine_tune_checkpoint), s)
    
    # tfrecord files train and test.
    s = re.sub(
        '(input_path: ".*?)(train.record)(.*?")', 'input_path: "{}"'.format(train_record_fname), s)
    s = re.sub(
        '(input_path: ".*?)(val.record)(.*?")', 'input_path: "{}"'.format(test_record_fname), s)

    # label_map_path
    s = re.sub(
        'label_map_path: ".*?"', 'label_map_path: "{}"'.format(label_map_pbtxt_fname), s)

    # Set training batch_size.
    s = re.sub('batch_size: [0-9]+',
               'batch_size: {}'.format(batch_size), s)

    # Set training steps, num_steps
    s = re.sub('num_steps: [0-9]+',
               'num_steps: {}'.format(num_steps), s)
    
    # Set number of classes num_classes.
    s = re.sub('num_classes: [0-9]+',
               'num_classes: {}'.format(num_classes), s)
    # Set number of classes num_classes.
    s = re.sub('iou_threshold: [0-9].[0-9]+',
               'iou_threshold: {}'.format(iou_threshold), s)
    
    f.write(s)

# %%
# #Have a look at the config file with various settings
# !cat {pipeline_fname}
# Out:
# # SSD with Mobilenet v2 configuration for MSCOCO Dataset.
# # Users should configure the fine_tune_checkpoint field in the train config as
# # well as the label_map_path and input_path fields in the train_input_reader and
# # eval_input_reader. Search for "PATH_TO_BE_CONFIGURED" to find the fields that
# # should be configured.
#
# model {
#   ssd {
#     num_classes: 2
#     box_coder {
#       faster_rcnn_box_coder {
#         y_scale: 10.0
#         x_scale: 10.0
#         height_scale: 5.0
#         width_scale: 5.0
#       }
#     }
#     matcher {
#       argmax_matcher {
#         matched_threshold: 0.5
#         unmatched_threshold: 0.5
#         ignore_thresholds: false
#         negatives_lower_than_unmatched: true
#         force_match_for_each_row: true
#       }
#     }
#     similarity_calculator {
#       iou_similarity {
#       }
#     }
#     anchor_generator {
#       ssd_anchor_generator {
#         num_layers: 6
#         min_scale: 0.2
#         max_scale: 0.95
#         aspect_ratios: 1.0
#         aspect_ratios: 2.0
#         aspect_ratios: 0.5
#         aspect_ratios: 3.0
#         aspect_ratios: 0.3333
#       }
#     }
#     image_resizer {
#       fixed_shape_resizer {
#         height: 300
#         width: 300
#       }
#     }
#     box_predictor {
#       convolutional_box_predictor {
#         min_depth: 0
#         max_depth: 0
#         num_layers_before_predictor: 0
#         use_dropout: false
#         dropout_keep_probability: 0.8
#         kernel_size: 1
#         box_code_size: 4
#         apply_sigmoid_to_scores: false
#         conv_hyperparams {
#           activation: RELU_6,
#           regularizer {
#             l2_regularizer {
#               weight: 0.00004
#             }
#           }
#           initializer {
#             truncated_normal_initializer {
#               stddev: 0.03
#               mean: 0.0
#             }
#           }
#           batch_norm {
#             train: true,
#             scale: true,
#             center: true,
#             decay: 0.9997,
#             epsilon: 0.001,
#           }
#         }
#       }
#     }
#     feature_extractor {
#       type: 'ssd_mobilenet_v2'
#       min_depth: 16
#       depth_multiplier: 1.0
#       conv_hyperparams {
#         activation: RELU_6,
#         regularizer {
#           l2_regularizer {
#             weight: 0.00004
#           }
#         }
#         initializer {
#           truncated_normal_initializer {
#             stddev: 0.03
#             mean: 0.0
#           }
#         }
#         batch_norm {
#           train: true,
#           scale: true,
#           center: true,
#           decay: 0.9997,
#           epsilon: 0.001,
#         }
#       }
#     }
#     loss {
#       classification_loss {
#         weighted_sigmoid {
#         }
#       }
#       localization_loss {
#         weighted_smooth_l1 {
#         }
#       }
#       hard_example_miner {
#         num_hard_examples: 3000
#         iou_threshold: 0.5
#         loss_type: CLASSIFICATION
#         max_negatives_per_positive: 3
#         min_negatives_per_image: 3
#       }
#       classification_weight: 1.0
#       localization_weight: 1.0
#     }
#     normalize_loss_by_num_matches: true
#     post_processing {
#       batch_non_max_suppression {
#         score_threshold: 1e-8
#         iou_threshold: 0.5
#         max_detections_per_class: 100
#         max_total_detections: 100
#       }
#       score_converter: SIGMOID
#     }
#   }
# }
#
# train_config: {
#   batch_size: 24
#   optimizer {
#     rms_prop_optimizer: {
#       learning_rate: {
#         exponential_decay_learning_rate {
#           initial_learning_rate: 0.004
#           decay_steps: 800720
#           decay_factor: 0.95
#         }
#       }
#       momentum_optimizer_value: 0.9
#       decay: 0.9
#       epsilon: 1.0
#     }
#   }
#   fine_tune_checkpoint: "/content/models/research/pretrained_model/model.ckpt"
#   fine_tune_checkpoint_type:  "detection"
#   # Note: The below line limits the training process to 200K steps, which we
#   # empirically found to be sufficient enough to train the pets dataset. This
#   # effectively bypasses the learning rate schedule (the learning rate will
#   # never decay). Remove the below line to train indefinitely.
#   num_steps: 5000
#   data_augmentation_options {
#     random_horizontal_flip {
#     }
#   }
#   data_augmentation_options {
#     ssd_random_crop {
#     }
#   }
# }
#
# train_input_reader: {
#   tf_record_input_reader {
#     input_path: "/content/object_detection_demo_flow/data/annotations/train.record"
#   }
#   label_map_path: "/content/object_detection_demo_flow/data/annotations/label_map.pbtxt"
# }
#
# eval_config: {
#   num_examples: 8000
#   # Note: The below line limits the evaluation process to 10 evaluations.
#   # Remove the below line to evaluate indefinitely.
#   max_evals: 10
# }
#
# eval_input_reader: {
#   tf_record_input_reader {
#     input_path: "/content/object_detection_demo_flow/data/annotations/test.record"
#   }
#   label_map_path: "/content/object_detection_demo_flow/data/annotations/label_map.pbtxt"
#   shuffle: false
#   num_readers: 1
# }

# %% [markdown]
# # Train the model

# %% [markdown]
# ## Start the training

# %%
# !echo {model_dir}
# Out:
# training/

# %%
model_dir = 'training/'

# !python /content/models/research/object_detection/model_main_tf2.py \
    --pipeline_config_path={pipeline_fname} \
    --model_dir={model_dir} \
    --alsologtostderr \
    --num_train_steps={num_steps} \
    --num_eval_steps={num_eval_steps}
# Out:
# python3: can't open file '/content/models/research/object_detection/model_main_tf2.py': [Errno 2] No such file or directory

# %%
 #show training model location
# !ls /object_detection_demo_flow/data/annotations
# Out:
# ls: cannot access '/object_detection_demo_flow/data/annotations': No such file or directory

# %% [markdown]
# ## Export a Trained Inference Graph
# Once your training job is complete, you need to extract the newly trained inference graph, which will be later used to perform the object detection. This can be done as follows:

# %%
#clean output_directory if necessary to start fresh:

# !rm -rf /content/object_detection_demo/fine_tuned_model/ 
# os.makedirs('/content/object_detection_demo_flow/fine_tuned_model/', exist_ok=True)

# %%
# %%capture
import re
import numpy as np

output_directory = './fine_tuned_model'
# output_directory = '/content/gdrive/My\ Drive/data/'

lst = os.listdir(model_dir)
lst = [l for l in lst if 'model.ckpt-' in l and '.meta' in l]
steps=np.array([int(re.findall('\d+', l)[0]) for l in lst])
last_model = lst[steps.argmax()].replace('.meta', '')

last_model_path = os.path.join(model_dir, last_model)
print(last_model_path)
# !python /content/models/research/object_detection/export_inference_graph.py \
    --input_type=image_tensor \
    --pipeline_config_path={pipeline_fname} \
    --output_directory={output_directory} \
    --trained_checkpoint_prefix={last_model_path}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-7268800adc00> in <module>()
#       5 # output_directory = '/content/gdrive/My\ Drive/data/'
#       6
# ----> 7 lst = os.listdir(model_dir)
#       8 lst = [l for l in lst if 'model.ckpt-' in l and '.meta' in l]
#       9 steps=np.array([int(re.findall('\d+', l)[0]) for l in lst])
#
# NameError: name 'os' is not defined

# %%
#export directory check
# !ls {output_directory}

# %%
import os
pb_fname = os.path.join(os.path.abspath(output_directory), "frozen_inference_graph.pb")
assert os.path.isfile(pb_fname), '`{}` not exist'.format(pb_fname)
# !ls -alh {pb_fname}
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-8-20af866201e5> in <module>()
#       1 import os
#       2 pb_fname = os.path.join(os.path.abspath(output_directory), "frozen_inference_graph.pb")
# ----> 3 assert os.path.isfile(pb_fname), '`{}` not exist'.format(pb_fname)
#       4 # !ls -alh {pb_fname}
#
# AssertionError: `/content/fine_tuned_model/frozen_inference_graph.pb` not exist

# %% [markdown]
# ## Checking is trained model work properly
# Test with images in repository `object_detection_demo_flow/data/images/final test` directory.

# %%
import os
import glob

# Path to frozen detection graph. This is the actual model that is used for the object detection.
PATH_TO_CKPT = pb_fname

# List of the strings that is used to add correct label for each box.
PATH_TO_LABELS = label_map_pbtxt_fname

# If you want to test the code with your images, just add images files to the PATH_TO_TEST_IMAGES_DIR.
PATH_TO_TEST_IMAGES_DIR =  os.path.join(repo_dir_path, "data/images/final_test")

assert os.path.isfile(pb_fname)
assert os.path.isfile(PATH_TO_LABELS)
TEST_IMAGE_PATHS = glob.glob(os.path.join(PATH_TO_TEST_IMAGES_DIR, "*.*"))
assert len(TEST_IMAGE_PATHS) > 0, 'No image found in `{}`.'.format(PATH_TO_TEST_IMAGES_DIR)
print(TEST_IMAGE_PATHS)

# %%
# %cd /content/models/research/object_detection

import numpy as np
import os
import six.moves.urllib as urllib
import sys
import tarfile
import tensorflow as tf
import zipfile

from collections import defaultdict
from io import StringIO
# This is needed to display the images.
# %matplotlib inline
import matplotlib.pyplot as plt
from PIL import Image

# This is needed since the notebook is stored in the object_detection folder.
sys.path.append("..")
from object_detection.utils import ops as utils_ops

from object_detection.utils import label_map_util

from object_detection.utils import visualization_utils as vis_util


detection_graph = tf.Graph()
with detection_graph.as_default():
    od_graph_def = tf.GraphDef()
    with tf.gfile.GFile(PATH_TO_CKPT, 'rb') as fid:
        serialized_graph = fid.read()
        od_graph_def.ParseFromString(serialized_graph)
        tf.import_graph_def(od_graph_def, name='')


label_map = label_map_util.load_labelmap(PATH_TO_LABELS)
categories = label_map_util.convert_label_map_to_categories(
    label_map, max_num_classes=num_classes, use_display_name=True)
category_index = label_map_util.create_category_index(categories)


def load_image_into_numpy_array(image):
    (im_width, im_height) = image.size
    return np.array(image.getdata()).reshape(
        (im_height, im_width, 3)).astype(np.uint8)

# Size, in inches, of the output images.
IMAGE_SIZE = (12, 8)


def run_inference_for_single_image(image, graph):
    with graph.as_default():
        with tf.Session() as sess:
            # Get handles to input and output tensors
            ops = tf.get_default_graph().get_operations()
            all_tensor_names = {
                output.name for op in ops for output in op.outputs}
            tensor_dict = {}
            for key in [
                'num_detections', 'detection_boxes', 'detection_scores',
                'detection_classes', 'detection_masks'
            ]:
                tensor_name = key + ':0'
                if tensor_name in all_tensor_names:
                    tensor_dict[key] = tf.get_default_graph().get_tensor_by_name(
                        tensor_name)
            if 'detection_masks' in tensor_dict:
                # The following processing is only for single image
                detection_boxes = tf.squeeze(
                    tensor_dict['detection_boxes'], [0])
                detection_masks = tf.squeeze(
                    tensor_dict['detection_masks'], [0])
                # Reframe is required to translate mask from box coordinates to image coordinates and fit the image size.
                real_num_detection = tf.cast(
                    tensor_dict['num_detections'][0], tf.int32)
                detection_boxes = tf.slice(detection_boxes, [0, 0], [
                                           real_num_detection, -1])
                detection_masks = tf.slice(detection_masks, [0, 0, 0], [
                                           real_num_detection, -1, -1])
                detection_masks_reframed = utils_ops.reframe_box_masks_to_image_masks(
                    detection_masks, detection_boxes, image.shape[0], image.shape[1])
                detection_masks_reframed = tf.cast(
                    tf.greater(detection_masks_reframed, 0.5), tf.uint8)
                # Follow the convention by adding back the batch dimension
                tensor_dict['detection_masks'] = tf.expand_dims(
                    detection_masks_reframed, 0)
            image_tensor = tf.get_default_graph().get_tensor_by_name('image_tensor:0')

            # Run inference
            output_dict = sess.run(tensor_dict,
                                   feed_dict={image_tensor: np.expand_dims(image, 0)})

            # all outputs are float32 numpy arrays, so convert types as appropriate
            output_dict['num_detections'] = int(
                output_dict['num_detections'][0])
            output_dict['detection_classes'] = output_dict[
                'detection_classes'][0].astype(np.uint8)
            output_dict['detection_boxes'] = output_dict['detection_boxes'][0]
            output_dict['detection_scores'] = output_dict['detection_scores'][0]
            if 'detection_masks' in output_dict:
                output_dict['detection_masks'] = output_dict['detection_masks'][0]
    return output_dict


for image_path in TEST_IMAGE_PATHS:
    image = Image.open(image_path)
    print(image_path)
    # the array based representation of the image will be used later in order to prepare the
    # result image with boxes and labels on it.
    image_np = load_image_into_numpy_array(image)
    # Expand dimensions since the model expects images to have shape: [1, None, None, 3]
    image_np_expanded = np.expand_dims(image_np, axis=0)
    # Actual detection.
    output_dict = run_inference_for_single_image(image_np, detection_graph)
    # Visualization of the results of a detection.
    vis_util.visualize_boxes_and_labels_on_image_array(
        image_np,
        output_dict['detection_boxes'],
        output_dict['detection_classes'],
        output_dict['detection_scores'],
        category_index,
        instance_masks=output_dict.get('detection_masks'),
        use_normalized_coordinates=True,
        line_thickness=8)
    plt.figure(figsize=IMAGE_SIZE)
    plt.imshow(image_np)
    plt.show()
